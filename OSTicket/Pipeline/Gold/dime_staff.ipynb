# %%
layer = "gold"
nm_gold = "dime_staff"
read_layer = "silver"
table = "staff"

# %%
# %run ../functions

# %%
df = spark.sql("""
               select id_staff, full_name, email_staff from osticket.silver.staff;
               """)
df.display()

# %%
write_table(df, layer, nm_gold)
