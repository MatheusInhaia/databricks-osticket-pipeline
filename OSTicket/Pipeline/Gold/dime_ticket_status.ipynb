# %%
layer = "gold"
nm_gold = "dime_ticket_status"
read_layer = "silver"
table = "ticket_status"

# %%
# %run ../functions

# %%
df = spark.sql("""
               select * from osticket.silver.ticket_status
               """)
df.display()

# %%
write_table(df, layer, nm_gold)
