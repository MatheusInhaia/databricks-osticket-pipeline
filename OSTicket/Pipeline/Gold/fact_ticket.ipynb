# %%
layer = "gold"
nm_gold = "fact_ticket"
read_layer = "silver"
table = "ticket"

# %%
# %run ../functions

# %%
# %sql
select * from osticket.silver.ticket
where id_status = 3 and created > '2025-12-01';

# %%
df = read_table(read_layer, table)
df.display()

# %%
write_table(df, layer, nm_gold)
