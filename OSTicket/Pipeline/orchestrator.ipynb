# %% [markdown]
# # **Rodar o pipeline de dados do OSTicket**

# %% [markdown]
# - ### **Bronze**

# %%
# %run ../Pipeline/Bronze/_landing-to-bronze

# %% [markdown]
# -  ### Silver

# %%
# %run ../Pipeline/Silver/ost_staff

# %%
# %run ../Pipeline/Silver/ost_thread_entry

# %%
# %run ../Pipeline/Silver/ost_thread_entry_agg

# %%
# %run ../Pipeline/Silver/ost_ticket_status

# %%
# %run ../Pipeline/Silver/ost_ticket

# %% [markdown]
# - ### **Gold**

# %%
# %run ../Pipeline/Gold/dime_staff

# %%
# %run ../Pipeline/Gold/dime_ticket_status

# %%
# %run ../Pipeline/Gold/dime_data

# %%
# %run ../Pipeline/Gold/fact_ticket

# %%
# %run ../Pipeline/Gold/fact_thread_entry_agg

# %%
# %run ../Pipeline/Gold/fact_kpi_staff

# %%
# %run ../Pipeline/Gold/fact_kpi_total

# %%
# %run ../Pipeline/Gold/kpi_sla_mensal

# %%
# %run ../Pipeline/Gold/ticket_report_staff

# %%
# %run ../Pipeline/Gold/ticket_report_status

# %% [markdown]
# Pipeline finalizado.
